# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/Credit_Card_Applications.csv")

# %%
# Separate features and target
X = df.drop(columns=["CustomerID", "Class"])
y = df["Class"]

# %% [markdown]
# ### Feature Selection
#
# - `CustomerID` was removed because it is a unique identifier and does not contain predictive information.
# - `Class` was separated as the target variable.
# - All remaining features were retained for model training.
